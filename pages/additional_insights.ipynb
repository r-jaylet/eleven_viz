# %%
import pandas as pd

from src.functions.get_data import get_data
from src.functions.gps import *
from src.functions.physical import *
from src.functions.recovery import *
from src.functions.additional_insights.compute_load_and_plot import compute_load_and_plot
from src.functions.additional_insights.plot_load_over_time import plot_load_over_time
from src.functions.recovery.plot_global_recovery_score import plot_global_recovery_score

from src.functions.additional_insights.plot_load_vs_recovery import plot_load_vs_recovery
from src.functions.additional_insights.plot_weekly_danger import plot_weekly_danger

# %%
df_gps = get_data("data/players_data/marc_cucurella/CFC GPS Data.csv")
df_physical = get_data("data/players_data/marc_cucurella/CFC Physical Capability Data.csv", encoding="utf-8-sig")
df_recovery = get_data("data/players_data/marc_cucurella/CFC Recovery status Data.csv")

# %%
threshold, df_load_by_date = compute_load_and_plot(df_gps, alpha=2, beta=1, gamma=3, top_x_percent=5, show_plot=False)

# %%
plot_load_over_time(df_load_by_date, "01/01/2023", "31/12/2023", rolling_window=7)
# Out:
# c:\Users\RémiJAYLET\Documents\eleven_viz\.venv\lib\site-packages\_plotly_utils\basevalidators.py:106: FutureWarning:
#
# The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result

# %%
df_recovery = plot_global_recovery_score(df_recovery, start_date='01/01/2023', end_date='31/12/2024', show_plot=True)
# Out:
# c:\Users\RémiJAYLET\Documents\eleven_viz\.venv\lib\site-packages\_plotly_utils\basevalidators.py:106: FutureWarning:
#
# The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result

# %%
merged_df = plot_load_vs_recovery(
    df_recovery, 
    df_gps, 
    start_date='01/06/2023', 
    end_date='31/05/2024', 
    alpha=2, 
    beta=1, 
    gamma=3, 
    top_x_percent=5, 
    show_plot=True,
    window_size=7
)

# %%
plot_weekly_danger(merged_df, 15)
# Out:
# c:\Users\RémiJAYLET\Documents\eleven_viz\.venv\lib\site-packages\_plotly_utils\basevalidators.py:106: FutureWarning:
#
# The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
